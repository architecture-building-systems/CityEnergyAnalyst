# %% [markdown]
# ### Update glossary.csv file using data from schemas.yml

# %%
import cea.scripts
import cea.inputlocator
import cea.config
import cea.glossary
from cea.tests.trace_inputlocator import get_csv_schema
import os
import yaml
import json

# %%
schemas = cea.scripts.schemas()
glossary_df = cea.glossary.read_glossary_df()
locators = schemas.keys()

# %% [markdown]
# ### start by finding all entries in schemas.yml without a schema

# %% [markdown]
# the following three locator methods need "special" treatment:
# - get_optimization_checkpoint
#   - "special" schema
# - get_optimization_disconnected_cooling_capacity
#   - only present in projects with cooling network
# - get_optimization_connected_cooling_capacity
#   - only present in projects with cooling network
#
# this code assumes you have a "reference-case-cooling/baseline" in your projectroot and have run the optimization on that (e.g. run `cea workflow --workflow district-cooling-system`)

# %%
config = cea.config.Configuration()
config.scenario = os.path.join(config.project, "..", "reference-case-cooling", "baseline")
locator = cea.inputlocator.InputLocator(scenario=config.scenario)

# load get_optimization_checkpoint schema
if not schemas["get_optimization_checkpoint"]["schema"]:
    with open(locator.get_optimization_checkpoint(1), 'r') as fp:
        get_optimization_checkpoint = json.load(fp)
    schemas["get_optimization_checkpoint"]["schema"] = {
        str(key): {"sample_data": get_optimization_checkpoint[key],
                   "types_found": None}
        for key in get_optimization_checkpoint.keys()
    }

# load get_optimization_disconnected_cooling_capacity schema
if not schemas["get_optimization_disconnected_cooling_capacity"]["schema"]:
    schemas["get_optimization_disconnected_cooling_capacity"]["schema"] = get_csv_schema(
        locator.get_optimization_disconnected_cooling_capacity(1, 1))
    
# load get_optimization_connected_cooling_capacity schema
if not schemas["get_optimization_connected_cooling_capacity"]["schema"]:
    schemas["get_optimization_connected_cooling_capacity"]["schema"] = get_csv_schema(
        locator.get_optimization_disconnected_cooling_capacity(1, 1))

# %%
# each locator method needs a "schema" entry (this should not output anything)
for lm in locators:
    if not "schema" in schemas[lm]:
        print lm

# %%
# the "schema" entry should not be `None` (this should not output anything)
for lm in locators:
    if not schemas[lm]["schema"]:
        print lm

# %% [markdown]
# if any of the above produce printed output, update schemas.yml and re-run the notebook

# %% [markdown]
# ### make sure the "used-by" and "created-by" lists don't contain duplicates

# %%
for lm in locators:
    if not "used_by" in schemas[lm]:
        print lm

# %%
for lm in locators:
    if not "created_by" in schemas[lm]:
        print lm

# %% [markdown]
# each locator should have a "used_by" and a "created_by" - let's assume they're all lists

# %%
for lm in locators:
    schemas[lm]["used_by"] = sorted(set(schemas[lm]["used_by"]))
    schemas[lm]["created_by"] = sorted(set(schemas[lm]["created_by"]))

# %%
# save it back
schemas_yml = os.path.join(os.path.dirname(cea.scripts.__file__), 'schemas.yml')
print "saving to:", schemas_yml
with open(schemas_yml, 'w') as fp:
    yaml.dump(schemas, fp)
schemas = cea.scripts.schemas()
# Out:
# saving to: c:\users\darthoma\documents\github\cityenergyanalyst\cea\schemas.yml

# %% [markdown]
# ### find all schema entries that are not in glossary.csv

# %%
# first: what are the missing locator methods?
glossary_lms = set(glossary_df.LOCATOR_METHOD.values)
schemas_lms = set(schemas.keys())
missing_lms = sorted(schemas_lms - glossary_lms)
print '\n'.join(missing_lms)

# %% [markdown]
# for each of those missing locator methods in glossary.csv, we need to append entries for each of the fields of that file. some of those files are special (the optimization checkpoints comes to mind). each glossary.csv entry has the following fields:
#
# - SCRIPT (use first "created_by" or "-", if input file)
# - LOCATOR_METHOD
# - FILE_NAME (get from schemas.yml file_path)
# - VARIABLE (this is the field name)
# - DESCRIPTION (use "TODO")
# - UNIT (use "TODO")
# - VALUES (use "TODO")
# - TYPE (use the first from schemas.types_found)
# - COLOR (use "black") - I'm not really sure we need this at all in glossary.csv?

# %%
for lm in missing_lms:
    script = schemas[lm]["created_by"][0] if len(schemas[lm]["created_by"]) else "-"
    file_name = schemas[lm]["file_path"]
    for variable in schemas[lm]["schema"].keys():
        if "types_found" in schemas[lm]["schema"][variable]:
            type = schemas[lm]["schema"][variable]["types_found"][0] if schemas[lm]["schema"][variable]["types_found"] else "TODO"
        else:
            type = "TODO"
        glossary_df = glossary_df.append({"key": "{lm}!!!{variable}".format(**locals()),
                                          "SCRIPT": script,
                                          "LOCATOR_METHOD": lm,
                                          "FILE_NAME": file_name,
                                          "VARIABLE": variable,
                                          "DESCRIPTION": "TODO",
                                          "UNIT": "TODO",
                                          "VALUES": "TODO",
                                          "TYPE": type,
                                          "COLOR": "black"}, ignore_index=True)
glossary_df.to_csv(os.path.join(os.path.dirname(cea.glossary.__file__), 'glossary.csv'),
                  columns=["SCRIPT", "LOCATOR_METHOD", "FILE_NAME", "VARIABLE", "DESCRIPTION", "UNIT", "VALUES", "TYPE", "COLOR"],
                  index=False)
print("saved new glossary.csv - reloading")
glossary_df = cea.glossary.read_glossary_df()
# Out:
# saved new glossary.csv - reloading

# %% [markdown]
# ### find all glossary entries that are not in schemas.yml

# %%
# find all locator methods not present in schemas.yml
for index, row in glossary_df.iterrows():
    lm = row["LOCATOR_METHOD"]
    if lm not in schemas:
        print lm, row["FILE_NAME"]
# Out:
# get_archetypes_system_controls databases/ch/archetypes/system_controls.xlsx:heating_cooling
# get_archetypes_system_controls databases/ch/archetypes/system_controls.xlsx:heating_cooling
# get_archetypes_system_controls databases/ch/archetypes/system_controls.xlsx:heating_cooling
# get_archetypes_system_controls databases/ch/archetypes/system_controls.xlsx:heating_cooling
# get_archetypes_system_controls databases/ch/archetypes/system_controls.xlsx:heating_cooling
# get_archetypes_system_controls databases/ch/archetypes/system_controls.xlsx:heating_cooling
# get_building_restrictions inputs/building-properties/restrictions.dbf
# get_building_restrictions inputs/building-properties/restrictions.dbf
# get_building_restrictions inputs/building-properties/restrictions.dbf
# get_building_restrictions inputs/building-properties/restrictions.dbf
# get_building_restrictions inputs/building-properties/restrictions.dbf
# get_building_restrictions inputs/building-properties/restrictions.dbf
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:EMBODIED
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:EMBODIED
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:EMBODIED
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:EMBODIED
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:EMBODIED
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:EMBODIED
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:EMBODIED
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:EMBODIED
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:EMBODIED
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:EMBODIED
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:EMBODIED
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:MOBILITY
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:MOBILITY
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:MOBILITY
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:MOBILITY
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:MOBILITY
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:MOBILITY
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:MOBILITY
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:MOBILITY
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:MOBILITY
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:MOBILITY
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:MOBILITY
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:OPERATION
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:OPERATION
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:OPERATION
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:OPERATION
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:OPERATION
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:OPERATION
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:OPERATION
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:OPERATION
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:OPERATION
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:OPERATION
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:OPERATION
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:TOTAL
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:TOTAL
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:TOTAL
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:TOTAL
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:TOTAL
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:TOTAL
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:TOTAL
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:TOTAL
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:TOTAL
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:TOTAL
# get_data_benchmark databases/sg/benchmarks/benchmark_2000w.xls:TOTAL
# get_edge_mass_flow_csv_file outputs/data/optimization/network/layout/nominal_edgemassflow_at_design_dh__kgpers.csv
# get_edge_mass_flow_csv_file outputs/data/optimization/network/layout/nominal_edgemassflow_at_design_dh__kgpers.csv
# get_envelope_systems databases/ch/systems/envelope_systems.xls:CONSTRUCTION
# get_envelope_systems databases/ch/systems/envelope_systems.xls:CONSTRUCTION
# get_envelope_systems databases/ch/systems/envelope_systems.xls:CONSTRUCTION
# get_envelope_systems databases/ch/systems/envelope_systems.xls:LEAKAGE
# get_envelope_systems databases/ch/systems/envelope_systems.xls:LEAKAGE
# get_envelope_systems databases/ch/systems/envelope_systems.xls:LEAKAGE
# get_envelope_systems databases/ch/systems/envelope_systems.xls:ROOF
# get_envelope_systems databases/ch/systems/envelope_systems.xls:ROOF
# get_envelope_systems databases/ch/systems/envelope_systems.xls:ROOF
# get_envelope_systems databases/ch/systems/envelope_systems.xls:ROOF
# get_envelope_systems databases/ch/systems/envelope_systems.xls:ROOF
# get_envelope_systems databases/ch/systems/envelope_systems.xls:ROOF
# get_envelope_systems databases/ch/systems/envelope_systems.xls:SHADING
# get_envelope_systems databases/ch/systems/envelope_systems.xls:SHADING
# get_envelope_systems databases/ch/systems/envelope_systems.xls:SHADING
# get_envelope_systems databases/ch/systems/envelope_systems.xls:WALL
# get_envelope_systems databases/ch/systems/envelope_systems.xls:WALL
# get_envelope_systems databases/ch/systems/envelope_systems.xls:WALL
# get_envelope_systems databases/ch/systems/envelope_systems.xls:WALL
# get_envelope_systems databases/ch/systems/envelope_systems.xls:WALL
# get_envelope_systems databases/ch/systems/envelope_systems.xls:WALL
# get_envelope_systems databases/ch/systems/envelope_systems.xls:WALL
# get_envelope_systems databases/ch/systems/envelope_systems.xls:WINDOW
# get_envelope_systems databases/ch/systems/envelope_systems.xls:WINDOW
# get_envelope_systems databases/ch/systems/envelope_systems.xls:WINDOW
# get_envelope_systems databases/ch/systems/envelope_systems.xls:WINDOW
# get_envelope_systems databases/ch/systems/envelope_systems.xls:WINDOW
# get_envelope_systems databases/ch/systems/envelope_systems.xls:WINDOW
# get_lake_potential outputs/data/potentials/lake_potential.csv
# get_lake_potential outputs/data/potentials/lake_potential.csv
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_EMISSIONS
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_building_systems databases/sg/lifecycle/lca_buildings.xlsx:EMBODIED_ENERGY
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:COOLING
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:COOLING
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:COOLING
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:COOLING
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:COOLING
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:COOLING
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:DHW
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:DHW
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:DHW
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:DHW
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:DHW
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:DHW
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:ELECTRICITY
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:ELECTRICITY
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:ELECTRICITY
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:ELECTRICITY
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:ELECTRICITY
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:ELECTRICITY
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:HEATING
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:HEATING
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:HEATING
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:HEATING
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:HEATING
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:HEATING
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:RESOURCES
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:RESOURCES
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:RESOURCES
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:RESOURCES
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:RESOURCES
# get_life_cycle_inventory_supply_systems databases/sg/lifecycle/lca_infrastructure.xlsx:RESOURCES
# get_network_node_types_csv_file outputs/data/optimization/network/layout/dh__nodes.csv
# get_network_node_types_csv_file outputs/data/optimization/network/layout/dh__nodes.csv
# get_network_node_types_csv_file outputs/data/optimization/network/layout/dh__nodes.csv
# get_network_node_types_csv_file outputs/data/optimization/network/layout/dh__nodes.csv
# get_network_node_types_csv_file outputs/data/optimization/network/layout/dh__nodes.csv
# get_network_node_types_csv_file outputs/data/optimization/network/layout/dh__nodes.csv
# get_network_node_types_csv_file outputs/data/optimization/network/layout/dh__nodes.csv
# get_network_node_types_csv_file outputs/data/optimization/network/layout/dh__nodes.csv
# get_network_node_types_csv_file outputs/data/optimization/network/layout/dh__nodes.csv
# get_network_node_types_csv_file outputs/data/optimization/network/layout/dh__nodes.csv
# get_node_mass_flow_csv_file outputs/data/optimization/network/layout/nominal_nodemassflow_at_design_dh__kgpers.csv
# get_node_mass_flow_csv_file outputs/data/optimization/network/layout/nominal_nodemassflow_at_design_dh__kgpers.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_list_file outputs/data/optimization/network/layout/dh__edges.csv
# get_optimization_network_edge_node_matrix_file outputs/data/optimization/network/layout/dh__edgenode.csv
# get_optimization_network_edge_node_matrix_file outputs/data/optimization/network/layout/dh__edgenode.csv
# get_optimization_network_layout_massflow_file outputs/data/optimization/network/layout/dh__massflow_kgs.csv
# get_optimization_network_layout_plant_heat_requirement_file outputs/data/optimization/network/layout/dh__plant_heat_requirement_kw.csv
# get_optimization_network_layout_ploss_system_edges_file outputs/data/optimization/network/layout/dh__ploss_system_edges_kw.csv
# get_optimization_network_layout_pressure_drop_file outputs/data/optimization/network/layout/dh__p_deltap_pa.csv
# get_optimization_network_layout_pressure_drop_file outputs/data/optimization/network/layout/dh__p_deltap_pa.csv
# get_optimization_network_layout_pressure_drop_file outputs/data/optimization/network/layout/dh__p_deltap_pa.csv
# get_optimization_network_layout_pressure_drop_file outputs/data/optimization/network/layout/dh__p_deltap_pa.csv
# get_optimization_network_layout_qloss_system_file outputs/data/optimization/network/layout/dh__qloss_system_kw.csv
# get_optimization_network_layout_return_temperature_file outputs/data/optimization/network/layout/dh__t_return_k.csv
# get_optimization_network_layout_supply_temperature_file outputs/data/optimization/network/layout/dh__t_supply_k.csv
# get_optimization_network_substation_ploss_file outputs/data/optimization/network/layout/dh__ploss_substations_kw.csv
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Absorption_chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:BH
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:Boiler
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CCGT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:CT
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:Chiller
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:FC
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:Furnace
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HEX
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:HP
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PV
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:PVT
# get_supply_systems databases/ch/systems/supply_systems.xls:Piping
# get_supply_systems databases/ch/systems/supply_systems.xls:Piping
# get_supply_systems databases/ch/systems/supply_systems.xls:Piping
# get_supply_systems databases/ch/systems/supply_systems.xls:Piping
# get_supply_systems databases/ch/systems/supply_systems.xls:Piping
# get_supply_systems databases/ch/systems/supply_systems.xls:Piping
# get_supply_systems databases/ch/systems/supply_systems.xls:Piping
# get_supply_systems databases/ch/systems/supply_systems.xls:Pricing
# get_supply_systems databases/ch/systems/supply_systems.xls:Pricing
# get_supply_systems databases/ch/systems/supply_systems.xls:Pricing
# get_supply_systems databases/ch/systems/supply_systems.xls:Pricing
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:Pump
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:SC
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_supply_systems databases/ch/systems/supply_systems.xls:TES
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:controller
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:controller
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:controller
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:controller
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:cooling
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:cooling
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:cooling
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:cooling
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:cooling
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:cooling
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:cooling
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:cooling
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:cooling
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:cooling
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:cooling
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:cooling
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:dhw
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:dhw
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:dhw
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:dhw
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:heating
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:heating
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:heating
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:heating
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:heating
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:heating
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:heating
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:heating
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:heating
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:heating
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:heating
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:heating
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:ventilation
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:ventilation
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:ventilation
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:ventilation
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:ventilation
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:ventilation
# get_technical_emission_systems databases/ch/systems/emission_systems.xls:ventilation
# get_thermal_network_layout_pressure_drop_kw_file outputs/data/thermal-network/dc__p_deltap_kw.csv
# get_thermal_network_layout_pressure_drop_kw_file outputs/data/thermal-network/dc__p_deltap_kw.csv
# get_thermal_network_layout_pressure_drop_kw_file outputs/data/thermal-network/dc__p_deltap_kw.csv
# get_thermal_network_layout_pressure_drop_kw_file outputs/data/thermal-network/dc__p_deltap_kw.csv
# get_thermal_network_qloss_system_file outputs/data/thermal-network/dc__p_deltap_kw.csv
# get_thermal_networks databases/ch/systems/thermal_networks.xls:MATERIAL PROPERTIES
# get_thermal_networks databases/ch/systems/thermal_networks.xls:MATERIAL PROPERTIES
# get_thermal_networks databases/ch/systems/thermal_networks.xls:MATERIAL PROPERTIES
# get_thermal_networks databases/ch/systems/thermal_networks.xls:MATERIAL PROPERTIES
# get_thermal_networks databases/ch/systems/thermal_networks.xls:MATERIAL PROPERTIES
# get_thermal_networks databases/ch/systems/thermal_networks.xls:PIPING CATALOG
# get_thermal_networks databases/ch/systems/thermal_networks.xls:PIPING CATALOG
# get_thermal_networks databases/ch/systems/thermal_networks.xls:PIPING CATALOG
# get_thermal_networks databases/ch/systems/thermal_networks.xls:PIPING CATALOG
# get_thermal_networks databases/ch/systems/thermal_networks.xls:PIPING CATALOG
# get_thermal_networks databases/ch/systems/thermal_networks.xls:PIPING CATALOG

# %% [markdown]
# ### make sure glossary.csv (locator_method, variable) is unique
