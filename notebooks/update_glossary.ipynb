# %% [markdown]
# ### Update glossary.csv file using data from schemas.yml

# %%
import cea.scripts
import cea.inputlocator
import cea.config
import cea.glossary
from cea.tests.trace_inputlocator import get_csv_schema
import os
import yaml
import json

# %%
schemas = cea.scripts.schemas()
glossary_df = cea.glossary.read_glossary_df()
locators = schemas.keys()

# %% [markdown]
# ### start by finding all entries in schemas.yml without a schema

# %% [markdown]
# the following three locator methods need "special" treatment:
# - get_optimization_checkpoint
#   - "special" schema
# - get_optimization_disconnected_cooling_capacity
#   - only present in projects with cooling network
# - get_optimization_connected_cooling_capacity
#   - only present in projects with cooling network
#
# this code assumes you have a "reference-case-cooling/baseline" in your projectroot and have run the optimization on that (e.g. run `cea workflow --workflow district-cooling-system`)

# %%
config = cea.config.Configuration()
config.scenario = os.path.join(config.project, "..", "reference-case-cooling", "baseline")
locator = cea.inputlocator.InputLocator(scenario=config.scenario)

# load get_optimization_checkpoint schema
if not schemas["get_optimization_checkpoint"]["schema"]:
    with open(locator.get_optimization_checkpoint(1), 'r') as fp:
        get_optimization_checkpoint = json.load(fp)
    schemas["get_optimization_checkpoint"]["schema"] = {
        str(key): {"sample_data": get_optimization_checkpoint[key],
                   "types_found": None}
        for key in get_optimization_checkpoint.keys()
    }

# load get_optimization_disconnected_cooling_capacity schema
if not schemas["get_optimization_disconnected_cooling_capacity"]["schema"]:
    schemas["get_optimization_disconnected_cooling_capacity"]["schema"] = get_csv_schema(
        locator.get_optimization_disconnected_cooling_capacity(1, 1))
    
# load get_optimization_connected_cooling_capacity schema
if not schemas["get_optimization_connected_cooling_capacity"]["schema"]:
    schemas["get_optimization_connected_cooling_capacity"]["schema"] = get_csv_schema(
        locator.get_optimization_disconnected_cooling_capacity(1, 1))

# %%
# each locator method needs a "schema" entry (this should not output anything)
for lm in locators:
    if not "schema" in schemas[lm]:
        print lm

# %%
# the "schema" entry should not be `None` (this should not output anything)
for lm in locators:
    if not schemas[lm]["schema"]:
        print lm

# %% [markdown]
# if any of the above produce printed output, update schemas.yml and re-run the notebook

# %% [markdown]
# ### make sure the "used-by" and "created-by" lists don't contain duplicates

# %%
for lm in locators:
    if not "used_by" in schemas[lm]:
        print lm

# %%
for lm in locators:
    if not "created_by" in schemas[lm]:
        print lm

# %% [markdown]
# each locator should have a "used_by" and a "created_by" - let's assume they're all lists

# %%
for lm in locators:
    schemas[lm]["used_by"] = sorted(set(schemas[lm]["used_by"]))
    schemas[lm]["created_by"] = sorted(set(schemas[lm]["created_by"]))

# %%
# save it back
schemas_yml = os.path.join(os.path.dirname(cea.scripts.__file__), 'schemas.yml')
print "saving to:", schemas_yml
with open(schemas_yml, 'w') as fp:
    yaml.dump(schemas, fp)
schemas = cea.scripts.schemas()
# Out:
# saving to: c:\users\darthoma\documents\github\cityenergyanalyst\cea\schemas.yml

# %% [markdown]
# ### find all schema entries that are not in glossary.csv

# %%
# first: what are the missing locator methods?
glossary_lms = set(glossary_df.LOCATOR_METHOD.values)
schemas_lms = set(schemas.keys())
missing_lms = sorted(schemas_lms - glossary_lms)
print '\n'.join(missing_lms)
# Out:
# get_building_weekly_schedules
# get_database_air_conditioning_systems
# get_database_envelope_systems
# get_database_lca_buildings
# get_database_lca_mobility
# get_database_standard_schedules_use
# get_database_supply_systems
# get_geothermal_potential
# get_multi_criteria_analysis
# get_network_energy_pumping_requirements_file
# get_network_linear_pressure_drop_edges
# get_network_linear_thermal_loss_edges_file
# get_network_pressure_at_nodes
# get_network_temperature_plant
# get_network_temperature_return_nodes_file
# get_network_temperature_supply_nodes_file
# get_network_thermal_loss_edges_file
# get_network_total_pressure_drop_file
# get_network_total_thermal_loss_file
# get_optimization_checkpoint
# get_optimization_connected_cooling_capacity
# get_optimization_connected_electricity_capacity
# get_optimization_connected_heating_capacity
# get_optimization_decentralized_folder_building_result_heating
# get_optimization_decentralized_folder_building_result_heating_activation
# get_optimization_disconnected_cooling_capacity
# get_optimization_disconnected_heating_capacity
# get_optimization_generation_connected_performance
# get_optimization_generation_disconnected_performance
# get_optimization_generation_total_performance
# get_optimization_generation_total_performance_halloffame
# get_optimization_generation_total_performance_pareto
# get_optimization_individuals_in_generation
# get_optimization_network_results_summary
# get_optimization_slave_building_connectivity
# get_optimization_slave_connected_performance
# get_optimization_slave_cooling_activation_pattern
# get_optimization_slave_disconnected_performance
# get_optimization_slave_electricity_activation_pattern
# get_optimization_slave_electricity_requirements_data
# get_optimization_slave_heating_activation_pattern
# get_optimization_slave_total_performance
# get_optimization_substations_results_file
# get_optimization_substations_total_file
# get_optimization_thermal_network_data_file
# get_radiation_building_sensors
# get_radiation_materials
# get_schedule_model_file
# get_thermal_network_edge_list_file
# get_thermal_network_layout_massflow_edges_file
# get_thermal_network_layout_massflow_nodes_file
# get_thermal_network_node_types_csv_file
# get_thermal_network_plant_heat_requirement_file
# get_thermal_network_pressure_losses_edges_file
# get_thermal_network_substation_ploss_file
# get_thermal_network_velocity_edges_file
# get_water_body_potential
# get_weather_file

# %% [markdown]
# for each of those missing locator methods in glossary.csv, we need to append entries for each of the fields of that file. some of those files are special (the optimization checkpoints comes to mind). each glossary.csv entry has the following fields:
#
# - SCRIPT (use first "created_by" or "-", if input file)
# - LOCATOR_METHOD
# - FILE_NAME (get from schemas.yml file_path)
# - VARIABLE (this is the field name)
# - DESCRIPTION (use "TODO")
# - UNIT (use "TODO")
# - VALUES (use "TODO")
# - TYPE (use the first from schemas.types_found)
# - COLOR (use "black") - I'm not really sure we need this at all in glossary.csv?

# %%
for lm in missing_lms:
    script = schemas[lm]["created_by"][0] if len(schemas[lm]["created_by"]) else "-"
    file_name = schemas[lm]["file_path"]
    for variable in schemas[lm]["schema"].keys():
        if "types_found" in schemas[lm]["schema"][variable]:
            type = schemas[lm]["schema"][variable]["types_found"][0] if schemas[lm]["schema"][variable]["types_found"] else "TODO"
        else:
            type = "TODO"
        glossary_df = glossary_df.append({"key": "{lm}!!!{variable}".format(**locals()),
                                          "SCRIPT": script,
                                          "LOCATOR_METHOD": lm,
                                          "FILE_NAME": file_name,
                                          "VARIABLE": variable,
                                          "DESCRIPTION": "TODO",
                                          "UNIT": "TODO",
                                          "VALUES": "TODO",
                                          "TYPE": type,
                                          "COLOR": "black"}, ignore_index=True)
glossary_df.to_csv(os.path.join(os.path.dirname(cea.glossary.__file__), 'glossary.csv'),
                  columns=["SCRIPT", "LOCATOR_METHOD", "FILE_NAME", "VARIABLE", "DESCRIPTION", "UNIT", "VALUES", "TYPE", "COLOR"],
                  index=False)
print("saved new glossary.csv - reloading")
glossary_df = cea.glossary.read_glossary_df()
# Out:
# saved new glossary.csv - reloading

# %% [markdown]
# ### find all glossary entries that are not in schemas.yml

# %%
for index, row in glossary_df.iterrows():
    print row["LOCATOR_METHOD"], row["VARIABLE"]
# Out:
# PVT_metadata_results AREA_m2
# PVT_metadata_results BUILDING
# PVT_metadata_results B_deg
# PVT_metadata_results CATB
# PVT_metadata_results CATGB
# PVT_metadata_results CATteta_z
# PVT_metadata_results SURFACE
# PVT_metadata_results TYPE
# PVT_metadata_results Xcoor
# PVT_metadata_results Xdir
# PVT_metadata_results Ycoor
# PVT_metadata_results Ydir
# PVT_metadata_results Zcoor
# PVT_metadata_results Zdir
# PVT_metadata_results area_installed_module_m2
# PVT_metadata_results array_spacing_m
# PVT_metadata_results orientation
# PVT_metadata_results surface
# PVT_metadata_results surface_azimuth_deg
# PVT_metadata_results tilt_deg
# PVT_metadata_results total_rad_Whm2
# PVT_metadata_results type_orientation
# PVT_results Area_PVT_m2
# PVT_results Date
# PVT_results E_PVT_gen_kWh
# PVT_results Eaux_PVT_kWh
# PVT_results PVT_roofs_top_E_kWh
# PVT_results PVT_roofs_top_Q_kWh
# PVT_results PVT_roofs_top_m2
# PVT_results PVT_walls_east_E_kWh
# PVT_results PVT_walls_east_Q_kWh
# PVT_results PVT_walls_east_m2
# PVT_results PVT_walls_north_E_kWh
# PVT_results PVT_walls_north_Q_kWh
# PVT_results PVT_walls_north_m2
# PVT_results PVT_walls_south_E_kWh
# PVT_results PVT_walls_south_Q_kWh
# PVT_results PVT_walls_south_m2
# PVT_results PVT_walls_west_E_kWh
# PVT_results PVT_walls_west_Q_kWh
# PVT_results PVT_walls_west_m2
# PVT_results Q_PVT_gen_kWh
# PVT_results Q_PVT_l_kWh
# PVT_results T_PVT_re_C
# PVT_results T_PVT_sup_C
# PVT_results mcp_PVT_kWperC
# PVT_results radiation_kWh
# PVT_total_buildings Area_PVT_m2
# PVT_total_buildings E_PVT_gen_kWh
# PVT_total_buildings Eaux_PVT_kWh
# PVT_total_buildings PVT_roofs_top_E_kWh
# PVT_total_buildings PVT_roofs_top_Q_kWh
# PVT_total_buildings PVT_roofs_top_m2
# PVT_total_buildings PVT_walls_east_E_kWh
# PVT_total_buildings PVT_walls_east_Q_kWh
# PVT_total_buildings PVT_walls_east_m2
# PVT_total_buildings PVT_walls_north_E_kWh
# PVT_total_buildings PVT_walls_north_Q_kWh
# PVT_total_buildings PVT_walls_north_m2
# PVT_total_buildings PVT_walls_south_E_kWh
# PVT_total_buildings PVT_walls_south_Q_kWh
# PVT_total_buildings PVT_walls_south_m2
# PVT_total_buildings PVT_walls_west_E_kWh
# PVT_total_buildings PVT_walls_west_Q_kWh
# PVT_total_buildings PVT_walls_west_m2
# PVT_total_buildings Q_PVT_gen_kWh
# PVT_total_buildings Q_PVT_l_kWh
# PVT_total_buildings Unnamed: 0
# PVT_total_buildings radiation_kWh
# PVT_totals Area_PVT_m2
# PVT_totals Date
# PVT_totals E_PVT_gen_kWh
# PVT_totals Eaux_PVT_kWh
# PVT_totals PVT_roofs_top_E_kWh
# PVT_totals PVT_roofs_top_Q_kWh
# PVT_totals PVT_roofs_top_m2
# PVT_totals PVT_walls_east_E_kWh
# PVT_totals PVT_walls_east_Q_kWh
# PVT_totals PVT_walls_east_m2
# PVT_totals PVT_walls_north_E_kWh
# PVT_totals PVT_walls_north_Q_kWh
# PVT_totals PVT_walls_north_m2
# PVT_totals PVT_walls_south_E_kWh
# PVT_totals PVT_walls_south_Q_kWh
# PVT_totals PVT_walls_south_m2
# PVT_totals PVT_walls_west_E_kWh
# PVT_totals PVT_walls_west_Q_kWh
# PVT_totals PVT_walls_west_m2
# PVT_totals Q_PVT_gen_kWh
# PVT_totals Q_PVT_l_kWh
# PVT_totals T_PVT_re_C
# PVT_totals T_PVT_sup_C
# PVT_totals mcp_PVT_kWperC
# PVT_totals radiation_kWh
# PV_metadata_results AREA_m2
# PV_metadata_results BUILDING
# PV_metadata_results B_deg
# PV_metadata_results CATB
# PV_metadata_results CATGB
# PV_metadata_results CATteta_z
# PV_metadata_results SURFACE
# PV_metadata_results TYPE
# PV_metadata_results Xcoor
# PV_metadata_results Xdir
# PV_metadata_results Ycoor
# PV_metadata_results Ydir
# PV_metadata_results Zcoor
# PV_metadata_results Zdir
# PV_metadata_results area_installed_module_m2
# PV_metadata_results array_spacing_m
# PV_metadata_results orientation
# PV_metadata_results surface
# PV_metadata_results surface_azimuth_deg
# PV_metadata_results tilt_deg
# PV_metadata_results total_rad_Whm2
# PV_metadata_results type_orientation
# PV_results Area_PV_m2
# PV_results Date
# PV_results E_PV_gen_kWh
# PV_results PV_roofs_top_E_kWh
# PV_results PV_roofs_top_m2
# PV_results PV_walls_east_E_kWh
# PV_results PV_walls_east_m2
# PV_results PV_walls_north_E_kWh
# PV_results PV_walls_north_m2
# PV_results PV_walls_south_E_kWh
# PV_results PV_walls_south_m2
# PV_results PV_walls_west_E_kWh
# PV_results PV_walls_west_m2
# PV_results radiation_kWh
# PV_total_buildings Area_PV_m2
# PV_total_buildings E_PV_gen_kWh
# PV_total_buildings PV_roofs_top_E_kWh
# PV_total_buildings PV_roofs_top_m2
# PV_total_buildings PV_walls_east_E_kWh
# PV_total_buildings PV_walls_east_m2
# PV_total_buildings PV_walls_north_E_kWh
# PV_total_buildings PV_walls_north_m2
# PV_total_buildings PV_walls_south_E_kWh
# PV_total_buildings PV_walls_south_m2
# PV_total_buildings PV_walls_west_E_kWh
# PV_total_buildings PV_walls_west_m2
# PV_total_buildings Unnamed: 0
# PV_total_buildings radiation_kWh
# PV_totals Area_PV_m2
# PV_totals Date
# PV_totals E_PV_gen_kWh
# PV_totals PV_roofs_top_E_kWh
# PV_totals PV_roofs_top_m2
# PV_totals PV_walls_east_E_kWh
# PV_totals PV_walls_east_m2
# PV_totals PV_walls_north_E_kWh
# PV_totals PV_walls_north_m2
# PV_totals PV_walls_south_E_kWh
# PV_totals PV_walls_south_m2
# PV_totals PV_walls_west_E_kWh
# PV_totals PV_walls_west_m2
# PV_totals radiation_kWh
# SC_metadata_results AREA_m2
# SC_metadata_results BUILDING
# SC_metadata_results B_deg
# SC_metadata_results CATB
# SC_metadata_results CATGB
# SC_metadata_results CATteta_z
# SC_metadata_results SURFACE
# SC_metadata_results TYPE
# SC_metadata_results Xcoor
# SC_metadata_results Xdir
# SC_metadata_results Ycoor
# SC_metadata_results Ydir
# SC_metadata_results Zcoor
# SC_metadata_results Zdir
# SC_metadata_results area_installed_module_m2
# SC_metadata_results array_spacing_m
# SC_metadata_results orientation
# SC_metadata_results surface
# SC_metadata_results surface_azimuth_deg
# SC_metadata_results tilt_deg
# SC_metadata_results total_rad_Whm2
# SC_metadata_results type_orientation
# SC_results Area_SC_m2
# SC_results Date
# SC_results Eaux_SC_kWh
# SC_results Q_SC_gen_kWh
# SC_results Q_SC_l_kWh
# SC_results SC_roofs_top_Q_kWh
# SC_results SC_roofs_top_m2
# SC_results SC_walls_east_Q_kWh
# SC_results SC_walls_east_m2
# SC_results SC_walls_north_Q_kWh
# SC_results SC_walls_north_m2
# SC_results SC_walls_south_Q_kWh
# SC_results SC_walls_south_m2
# SC_results SC_walls_west_Q_kWh
# SC_results SC_walls_west_m2
# SC_results T_SC_re_C
# SC_results T_SC_sup_C
# SC_results mcp_SC_kWperC
# SC_results radiation_kWh
# SC_total_buildings Area_SC_m2
# SC_total_buildings Eaux_SC_kWh
# SC_total_buildings Q_SC_gen_kWh
# SC_total_buildings Q_SC_l_kWh
# SC_total_buildings SC_roofs_top_Q_kWh
# SC_total_buildings SC_roofs_top_m2
# SC_total_buildings SC_walls_east_Q_kWh
# SC_total_buildings SC_walls_east_m2
# SC_total_buildings SC_walls_north_Q_kWh
# SC_total_buildings SC_walls_north_m2
# SC_total_buildings SC_walls_south_Q_kWh
# SC_total_buildings SC_walls_south_m2
# SC_total_buildings SC_walls_west_Q_kWh
# SC_total_buildings SC_walls_west_m2
# SC_total_buildings Unnamed: 0
# SC_total_buildings radiation_kWh
# SC_totals Area_SC_m2
# SC_totals Date
# SC_totals Eaux_SC_kWh
# SC_totals Q_SC_gen_kWh
# SC_totals Q_SC_l_kWh
# SC_totals SC_roofs_top_Q_kWh
# SC_totals SC_roofs_top_m2
# SC_totals SC_walls_east_Q_kWh
# SC_totals SC_walls_east_m2
# SC_totals SC_walls_north_Q_kWh
# SC_totals SC_walls_north_m2
# SC_totals SC_walls_south_Q_kWh
# SC_totals SC_walls_south_m2
# SC_totals SC_walls_west_Q_kWh
# SC_totals SC_walls_west_m2
# SC_totals T_SC_re_C
# SC_totals T_SC_sup_C
# SC_totals mcp_SC_kWperC
# SC_totals radiation_kWh
# get_archetypes_properties Es
# get_archetypes_properties Hs_ag
# get_archetypes_properties Hs_bg
# get_archetypes_properties Ns
# get_archetypes_properties building_use
# get_archetypes_properties standard
# get_archetypes_properties type_cons
# get_archetypes_properties type_leak
# get_archetypes_properties type_roof
# get_archetypes_properties type_shade
# get_archetypes_properties type_wall
# get_archetypes_properties type_win
# get_archetypes_properties void_deck
# get_archetypes_properties wwr_east
# get_archetypes_properties wwr_north
# get_archetypes_properties wwr_south
# get_archetypes_properties wwr_west
# get_archetypes_properties year_end
# get_archetypes_properties year_start
# get_archetypes_properties building_use
# get_archetypes_properties cool_ends
# get_archetypes_properties cool_starts
# get_archetypes_properties heat_ends
# get_archetypes_properties heat_starts
# get_archetypes_properties standard
# get_archetypes_properties type_cs
# get_archetypes_properties type_ctrl
# get_archetypes_properties type_dhw
# get_archetypes_properties type_hs
# get_archetypes_properties type_vent
# get_archetypes_properties year_end
# get_archetypes_properties year_start
# get_archetypes_properties Code
# get_archetypes_properties RH_max_pc
# get_archetypes_properties RH_min_pc
# get_archetypes_properties Tcs_set_C
# get_archetypes_properties Tcs_setb_C
# get_archetypes_properties Ths_set_C
# get_archetypes_properties Ths_setb_C
# get_archetypes_properties Ve_lpspax
# get_archetypes_properties Code
# get_archetypes_properties Ea_Wm2
# get_archetypes_properties Ed_Wm2
# get_archetypes_properties El_Wm2
# get_archetypes_properties Epro_Wm2
# get_archetypes_properties Qcpro_Wm2
# get_archetypes_properties Qcre_Wm2
# get_archetypes_properties Qhpro_Wm2
# get_archetypes_properties Qs_Wpax
# get_archetypes_properties Vw_lpdpax
# get_archetypes_properties Vww_lpdpax
# get_archetypes_properties X_ghpax
# get_archetypes_properties building_use
# get_archetypes_properties standard
# get_archetypes_properties type_cs
# get_archetypes_properties type_dhw
# get_archetypes_properties type_el
# get_archetypes_properties type_hs
# get_archetypes_properties year_end
# get_archetypes_properties year_start
# get_archetypes_system_controls cooling-season-end
# get_archetypes_system_controls cooling-season-start
# get_archetypes_system_controls has-cooling-season
# get_archetypes_system_controls has-heating-season
# get_archetypes_system_controls heating-season-end
# get_archetypes_system_controls heating-season-start
# get_building_age HVAC
# get_building_age Name
# get_building_age basement
# get_building_age built
# get_building_age envelope
# get_building_age partitions
# get_building_age roof
# get_building_age windows
# get_building_air_conditioning Name
# get_building_air_conditioning cool_ends
# get_building_air_conditioning cool_starts
# get_building_air_conditioning heat_ends
# get_building_air_conditioning heat_starts
# get_building_air_conditioning type_cs
# get_building_air_conditioning type_ctrl
# get_building_air_conditioning type_dhw
# get_building_air_conditioning type_hs
# get_building_air_conditioning type_vent
# get_building_architecture Es
# get_building_architecture Hs_ag
# get_building_architecture Hs_bg
# get_building_architecture Name
# get_building_architecture Ns
# get_building_architecture type_cons
# get_building_architecture type_leak
# get_building_architecture type_roof
# get_building_architecture type_shade
# get_building_architecture type_wall
# get_building_architecture type_win
# get_building_architecture void_deck
# get_building_architecture wwr_east
# get_building_architecture wwr_north
# get_building_architecture wwr_south
# get_building_architecture wwr_west
# get_building_comfort Name
# get_building_comfort RH_max_pc
# get_building_comfort RH_min_pc
# get_building_comfort Tcs_set_C
# get_building_comfort Tcs_setb_C
# get_building_comfort Ths_set_C
# get_building_comfort Ths_setb_C
# get_building_comfort Ve_lpspax
# get_building_internal Ea_Wm2
# get_building_internal Ed_Wm2
# get_building_internal El_Wm2
# get_building_internal Epro_Wm2
# get_building_internal Name
# get_building_internal Occ_m2pax
# get_building_internal Qcpro_Wm2
# get_building_internal Qcre_Wm2
# get_building_internal Qhpro_Wm2
# get_building_internal Qs_Wpax
# get_building_internal Vw_lpdpax
# get_building_internal Vww_lpdpax
# get_building_internal X_ghpax
# get_building_occupancy COOLROOM
# get_building_occupancy FOODSTORE
# get_building_occupancy GYM
# get_building_occupancy HOSPITAL
# get_building_occupancy HOTEL
# get_building_occupancy INDUSTRIAL
# get_building_occupancy LIBRARY
# get_building_occupancy MULTI_RES
# get_building_occupancy Name
# get_building_occupancy OFFICE
# get_building_occupancy PARKING
# get_building_occupancy RESTAURANT
# get_building_occupancy RETAIL
# get_building_occupancy SCHOOL
# get_building_occupancy SERVERROOM
# get_building_occupancy SINGLE_RES
# get_building_occupancy SWIMMING
# get_building_restrictions BIOGAS
# get_building_restrictions GEOTHERMAL
# get_building_restrictions NATURALGAS
# get_building_restrictions Name
# get_building_restrictions SOLAR
# get_building_restrictions WATERBODY
# get_building_supply Name
# get_building_supply type_cs
# get_building_supply type_dhw
# get_building_supply type_el
# get_building_supply type_hs
# get_building_weekly_schedules METADATA
# get_building_weekly_schedules mixed-schedule
# get_costs_operation_file Aocc_m2
# get_costs_operation_file COAL_hs_cost_m2yr
# get_costs_operation_file COAL_hs_cost_yr
# get_costs_operation_file COAL_ww_cost_m2yr
# get_costs_operation_file COAL_ww_cost_yr
# get_costs_operation_file DC_cdata_cost_m2yr
# get_costs_operation_file DC_cdata_cost_yr
# get_costs_operation_file DC_cre_cost_m2yr
# get_costs_operation_file DC_cre_cost_yr
# get_costs_operation_file DC_cs_cost_m2yr
# get_costs_operation_file DC_cs_cost_yr
# get_costs_operation_file DH_hs_cost_m2yr
# get_costs_operation_file DH_hs_cost_yr
# get_costs_operation_file DH_ww_cost_m2yr
# get_costs_operation_file DH_ww_cost_yr
# get_costs_operation_file GRID_cost_m2yr
# get_costs_operation_file GRID_cost_yr
# get_costs_operation_file NG_hs_cost_m2yr
# get_costs_operation_file NG_hs_cost_yr
# get_costs_operation_file NG_ww_cost_m2yr
# get_costs_operation_file NG_ww_cost_yr
# get_costs_operation_file Name
# get_costs_operation_file OIL_hs_cost_m2yr
# get_costs_operation_file OIL_hs_cost_yr
# get_costs_operation_file OIL_ww_cost_m2yr
# get_costs_operation_file OIL_ww_cost_yr
# get_costs_operation_file PV_cost_m2yr
# get_costs_operation_file PV_cost_yr
# get_costs_operation_file SOLAR_hs_cost_m2yr
# get_costs_operation_file SOLAR_hs_cost_yr
# get_costs_operation_file SOLAR_ww_cost_m2yr
# get_costs_operation_file SOLAR_ww_cost_yr
# get_costs_operation_file WOOD_hs_cost_m2yr
# get_costs_operation_file WOOD_hs_cost_yr
# get_costs_operation_file WOOD_ww_cost_m2yr
# get_costs_operation_file WOOD_ww_cost_yr
# get_data_benchmark CO2_target_new
# get_data_benchmark CO2_target_retrofit
# get_data_benchmark CO2_today
# get_data_benchmark Description
# get_data_benchmark NRE_target_new
# get_data_benchmark NRE_target_retrofit
# get_data_benchmark NRE_today
# get_data_benchmark PEN_target_new
# get_data_benchmark PEN_target_retrofit
# get_data_benchmark PEN_today
# get_data_benchmark code
# get_data_benchmark CO2_target_new
# get_data_benchmark CO2_target_retrofit
# get_data_benchmark CO2_today
# get_data_benchmark Description
# get_data_benchmark NRE_target_new
# get_data_benchmark NRE_target_retrofit
# get_data_benchmark NRE_today
# get_data_benchmark PEN_target_new
# get_data_benchmark PEN_target_retrofit
# get_data_benchmark PEN_today
# get_data_benchmark code
# get_data_benchmark CO2_target_new
# get_data_benchmark CO2_target_retrofit
# get_data_benchmark CO2_today
# get_data_benchmark Description
# get_data_benchmark NRE_target_new
# get_data_benchmark NRE_target_retrofit
# get_data_benchmark NRE_today
# get_data_benchmark PEN_target_new
# get_data_benchmark PEN_target_retrofit
# get_data_benchmark PEN_today
# get_data_benchmark code
# get_data_benchmark CO2_target_new
# get_data_benchmark CO2_target_retrofit
# get_data_benchmark CO2_today
# get_data_benchmark Description
# get_data_benchmark NRE_target_new
# get_data_benchmark NRE_target_retrofit
# get_data_benchmark NRE_today
# get_data_benchmark PEN_target_new
# get_data_benchmark PEN_target_retrofit
# get_data_benchmark PEN_today
# get_data_benchmark code
# get_database_air_conditioning_systems controller
# get_database_air_conditioning_systems cooling
# get_database_air_conditioning_systems dhw
# get_database_air_conditioning_systems heating
# get_database_air_conditioning_systems ventilation
# get_database_envelope_systems CONSTRUCTION
# get_database_envelope_systems LEAKAGE
# get_database_envelope_systems ROOF
# get_database_envelope_systems SHADING
# get_database_envelope_systems WALL
# get_database_envelope_systems WINDOW
# get_database_lca_buildings EMBODIED_EMISSIONS
# get_database_lca_buildings EMBODIED_ENERGY
# get_database_lca_mobility MOBILITY
# get_database_standard_schedules_use CH-SIA-2014
# get_database_standard_schedules_use METADATA
# get_database_standard_schedules_use RESTAURANT
# get_database_supply_systems ALL_IN_ONE_SYSTEMS
# get_database_supply_systems Absorption_chiller
# get_database_supply_systems BH
# get_database_supply_systems Boiler
# get_database_supply_systems CCGT
# get_database_supply_systems CT
# get_database_supply_systems Chiller
# get_database_supply_systems DETAILED_ELEC_PRICES
# get_database_supply_systems FC
# get_database_supply_systems FEEDSTOCKS
# get_database_supply_systems Furnace
# get_database_supply_systems HEX
# get_database_supply_systems HP
# get_database_supply_systems PIPING
# get_database_supply_systems PV
# get_database_supply_systems PVT
# get_database_supply_systems Pump
# get_database_supply_systems SC
# get_database_supply_systems TES
# get_demand_results_file COAL_hs_kWh
# get_demand_results_file COAL_ww_kWh
# get_demand_results_file DATE
# get_demand_results_file DC_cdata_kWh
# get_demand_results_file DC_cre_kWh
# get_demand_results_file DC_cs_kWh
# get_demand_results_file DH_hs_kWh
# get_demand_results_file DH_ww_kWh
# get_demand_results_file E_cdata_kWh
# get_demand_results_file E_cre_kWh
# get_demand_results_file E_cs_kWh
# get_demand_results_file E_hs_kWh
# get_demand_results_file E_sys_kWh
# get_demand_results_file E_ww_kWh
# get_demand_results_file Eal_kWh
# get_demand_results_file Eaux_kWh
# get_demand_results_file Edata_kWh
# get_demand_results_file Epro_kWh
# get_demand_results_file GRID_a_kWh
# get_demand_results_file GRID_aux_kWh
# get_demand_results_file GRID_cdata_kWh
# get_demand_results_file GRID_cre_kWh
# get_demand_results_file GRID_cs_kWh
# get_demand_results_file GRID_data_kWh
# get_demand_results_file GRID_hs_kWh
# get_demand_results_file GRID_kWh
# get_demand_results_file GRID_l_kWh
# get_demand_results_file GRID_pro_kWh
# get_demand_results_file GRID_ww_kWh
# get_demand_results_file I_rad_kWh
# get_demand_results_file I_sol_and_I_rad_kWh
# get_demand_results_file I_sol_kWh
# get_demand_results_file NG_hs_kWh
# get_demand_results_file NG_ww_kWh
# get_demand_results_file Name
# get_demand_results_file OIL_hs_kWh
# get_demand_results_file OIL_ww_kWh
# get_demand_results_file PV_kWh
# get_demand_results_file QC_sys_kWh
# get_demand_results_file QH_sys_kWh
# get_demand_results_file Q_gain_lat_peop_kWh
# get_demand_results_file Q_gain_sen_app_kWh
# get_demand_results_file Q_gain_sen_base_kWh
# get_demand_results_file Q_gain_sen_data_kWh
# get_demand_results_file Q_gain_sen_light_kWh
# get_demand_results_file Q_gain_sen_peop_kWh
# get_demand_results_file Q_gain_sen_pro_kWh
# get_demand_results_file Q_gain_sen_roof_kWh
# get_demand_results_file Q_gain_sen_vent_kWh
# get_demand_results_file Q_gain_sen_wall_kWh
# get_demand_results_file Q_gain_sen_wind_kWh
# get_demand_results_file Q_loss_sen_ref_kWh
# get_demand_results_file Qcdata_kWh
# get_demand_results_file Qcdata_sys_kWh
# get_demand_results_file Qcpro_sys_kWh
# get_demand_results_file Qcre_kWh
# get_demand_results_file Qcre_sys_kWh
# get_demand_results_file Qcs_dis_ls_kWh
# get_demand_results_file Qcs_em_ls_kWh
# get_demand_results_file Qcs_kWh
# get_demand_results_file Qcs_lat_ahu_kWh
# get_demand_results_file Qcs_lat_aru_kWh
# get_demand_results_file Qcs_lat_sys_kWh
# get_demand_results_file Qcs_sen_ahu_kWh
# get_demand_results_file Qcs_sen_aru_kWh
# get_demand_results_file Qcs_sen_scu_kWh
# get_demand_results_file Qcs_sen_sys_kWh
# get_demand_results_file Qcs_sys_ahu_kWh
# get_demand_results_file Qcs_sys_aru_kWh
# get_demand_results_file Qcs_sys_kWh
# get_demand_results_file Qcs_sys_scu_kWh
# get_demand_results_file Qhpro_sys_kWh
# get_demand_results_file Qhs_dis_ls_kWh
# get_demand_results_file Qhs_em_ls_kWh
# get_demand_results_file Qhs_kWh
# get_demand_results_file Qhs_lat_ahu_kWh
# get_demand_results_file Qhs_lat_aru_kWh
# get_demand_results_file Qhs_lat_sys_kWh
# get_demand_results_file Qhs_sen_ahu_kWh
# get_demand_results_file Qhs_sen_aru_kWh
# get_demand_results_file Qhs_sen_shu_kWh
# get_demand_results_file Qhs_sen_sys_kWh
# get_demand_results_file Qhs_sys_ahu_kWh
# get_demand_results_file Qhs_sys_aru_kWh
# get_demand_results_file Qhs_sys_kWh
# get_demand_results_file Qhs_sys_shu_kWh
# get_demand_results_file Qww_kWh
# get_demand_results_file Qww_sys_kWh
# get_demand_results_file SOLAR_hs_kWh
# get_demand_results_file SOLAR_ww_kWh
# get_demand_results_file T_ext_C
# get_demand_results_file T_int_C
# get_demand_results_file Tcdata_sys_re_C
# get_demand_results_file Tcdata_sys_sup_C
# get_demand_results_file Tcre_sys_re_C
# get_demand_results_file Tcre_sys_sup_C
# get_demand_results_file Tcs_sys_re_C
# get_demand_results_file Tcs_sys_re_ahu_C
# get_demand_results_file Tcs_sys_re_aru_C
# get_demand_results_file Tcs_sys_re_scu_C
# get_demand_results_file Tcs_sys_sup_C
# get_demand_results_file Tcs_sys_sup_ahu_C
# get_demand_results_file Tcs_sys_sup_aru_C
# get_demand_results_file Tcs_sys_sup_scu_C
# get_demand_results_file Ths_sys_re_C
# get_demand_results_file Ths_sys_re_ahu_C
# get_demand_results_file Ths_sys_re_aru_C
# get_demand_results_file Ths_sys_re_shu_C
# get_demand_results_file Ths_sys_sup_C
# get_demand_results_file Ths_sys_sup_ahu_C
# get_demand_results_file Ths_sys_sup_aru_C
# get_demand_results_file Ths_sys_sup_shu_C
# get_demand_results_file Tww_sys_re_C
# get_demand_results_file Tww_sys_sup_C
# get_demand_results_file WOOD_hs_kWh
# get_demand_results_file WOOD_ww_kWh
# get_demand_results_file mcpcdata_sys_kWperC
# get_demand_results_file mcpcre_sys_kWperC
# get_demand_results_file mcpcs_sys_ahu_kWperC
# get_demand_results_file mcpcs_sys_aru_kWperC
# get_demand_results_file mcpcs_sys_kWperC
# get_demand_results_file mcpcs_sys_scu_kWperC
# get_demand_results_file mcphs_sys_ahu_kWperC
# get_demand_results_file mcphs_sys_aru_kWperC
# get_demand_results_file mcphs_sys_kWperC
# get_demand_results_file mcphs_sys_shu_kWperC
# get_demand_results_file mcptw_kWperC
# get_demand_results_file mcpww_sys_kWperC
# get_demand_results_file people
# get_demand_results_file theta_o_C
# get_demand_results_file x_int
# get_edge_mass_flow_csv_file PIPE0
# get_edge_mass_flow_csv_file Unnamed: 0
# get_envelope_systems Cm_Af
# get_envelope_systems Description
# get_envelope_systems code
# get_envelope_systems Description
# get_envelope_systems code
# get_envelope_systems n50
# get_envelope_systems Description
# get_envelope_systems U_roof
# get_envelope_systems a_roof
# get_envelope_systems code
# get_envelope_systems e_roof
# get_envelope_systems r_roof
# get_envelope_systems Description
# get_envelope_systems code
# get_envelope_systems rf_sh
# get_envelope_systems Description
# get_envelope_systems U_base
# get_envelope_systems U_wall
# get_envelope_systems a_wall
# get_envelope_systems code
# get_envelope_systems e_wall
# get_envelope_systems r_wall
# get_envelope_systems Description
# get_envelope_systems F_F
# get_envelope_systems G_win
# get_envelope_systems U_win
# get_envelope_systems code
# get_envelope_systems e_win
# get_geothermal_potential Area_avail_m2
# get_geothermal_potential QGHP_kW
# get_geothermal_potential Ts_C
# get_lake_potential hour
# get_lake_potential lake_potential
# get_lca_embodied E_ghg_kgm2
# get_lca_embodied E_ghg_ton
# get_lca_embodied E_nre_pen_GJ
# get_lca_embodied E_nre_pen_MJm2
# get_lca_embodied GFA_m2
# get_lca_embodied Name
# get_lca_mobility GFA_m2
# get_lca_mobility M_ghg_kgm2
# get_lca_mobility M_ghg_ton
# get_lca_mobility M_nre_pen_GJ
# get_lca_mobility M_nre_pen_MJm2
# get_lca_mobility Name
# get_lca_operation COAL_hs_ghg_kgm2
# get_lca_operation COAL_hs_ghg_ton
# get_lca_operation COAL_hs_nre_pen_GJ
# get_lca_operation COAL_hs_nre_pen_MJm2
# get_lca_operation COAL_ww_ghg_kgm2
# get_lca_operation COAL_ww_ghg_ton
# get_lca_operation COAL_ww_nre_pen_GJ
# get_lca_operation COAL_ww_nre_pen_MJm2
# get_lca_operation DC_cdata_ghg_kgm2
# get_lca_operation DC_cdata_ghg_ton
# get_lca_operation DC_cdata_nre_pen_GJ
# get_lca_operation DC_cdata_nre_pen_MJm2
# get_lca_operation DC_cre_ghg_kgm2
# get_lca_operation DC_cre_ghg_ton
# get_lca_operation DC_cre_nre_pen_GJ
# get_lca_operation DC_cre_nre_pen_MJm2
# get_lca_operation DC_cs_ghg_kgm2
# get_lca_operation DC_cs_ghg_ton
# get_lca_operation DC_cs_nre_pen_GJ
# get_lca_operation DC_cs_nre_pen_MJm2
# get_lca_operation DH_hs_ghg_kgm2
# get_lca_operation DH_hs_ghg_ton
# get_lca_operation DH_hs_nre_pen_GJ
# get_lca_operation DH_hs_nre_pen_MJm2
# get_lca_operation DH_ww_ghg_kgm2
# get_lca_operation DH_ww_ghg_ton
# get_lca_operation DH_ww_nre_pen_GJ
# get_lca_operation DH_ww_nre_pen_MJm2
# get_lca_operation GFA_m2
# get_lca_operation GFA_m2.1
# get_lca_operation GRID_ghg_kgm2
# get_lca_operation GRID_ghg_ton
# get_lca_operation GRID_nre_pen_GJ
# get_lca_operation GRID_nre_pen_MJm2
# get_lca_operation NG_hs_ghg_kgm2
# get_lca_operation NG_hs_ghg_ton
# get_lca_operation NG_hs_nre_pen_GJ
# get_lca_operation NG_hs_nre_pen_MJm2
# get_lca_operation NG_ww_ghg_kgm2
# get_lca_operation NG_ww_ghg_ton
# get_lca_operation NG_ww_nre_pen_GJ
# get_lca_operation NG_ww_nre_pen_MJm2
# get_lca_operation Name
# get_lca_operation Name.1
# get_lca_operation OIL_hs_ghg_kgm2
# get_lca_operation OIL_hs_ghg_ton
# get_lca_operation OIL_hs_nre_pen_GJ
# get_lca_operation OIL_hs_nre_pen_MJm2
# get_lca_operation OIL_ww_ghg_kgm2
# get_lca_operation OIL_ww_ghg_ton
# get_lca_operation OIL_ww_nre_pen_GJ
# get_lca_operation OIL_ww_nre_pen_MJm2
# get_lca_operation O_ghg_kgm2
# get_lca_operation O_ghg_ton
# get_lca_operation O_nre_pen_GJ
# get_lca_operation O_nre_pen_MJm2
# get_lca_operation PV_ghg_kgm2
# get_lca_operation PV_ghg_kgm2.1
# get_lca_operation PV_ghg_ton
# get_lca_operation PV_ghg_ton.1
# get_lca_operation PV_nre_pen_GJ
# get_lca_operation PV_nre_pen_GJ.1
# get_lca_operation PV_nre_pen_MJm2
# get_lca_operation PV_nre_pen_MJm2.1
# get_lca_operation SOLAR_hs_ghg_kgm2
# get_lca_operation SOLAR_hs_ghg_ton
# get_lca_operation SOLAR_hs_nre_pen_GJ
# get_lca_operation SOLAR_hs_nre_pen_MJm2
# get_lca_operation SOLAR_ww_ghg_kgm2
# get_lca_operation SOLAR_ww_ghg_ton
# get_lca_operation SOLAR_ww_nre_pen_GJ
# get_lca_operation SOLAR_ww_nre_pen_MJm2
# get_lca_operation WOOD_hs_ghg_kgm2
# get_lca_operation WOOD_hs_ghg_ton
# get_lca_operation WOOD_hs_nre_pen_GJ
# get_lca_operation WOOD_hs_nre_pen_MJm2
# get_lca_operation WOOD_ww_ghg_kgm2
# get_lca_operation WOOD_ww_ghg_ton
# get_lca_operation WOOD_ww_nre_pen_GJ
# get_lca_operation WOOD_ww_nre_pen_MJm2
# get_life_cycle_inventory_building_systems Excavation
# get_life_cycle_inventory_building_systems Floor_g
# get_life_cycle_inventory_building_systems Floor_int
# get_life_cycle_inventory_building_systems Roof
# get_life_cycle_inventory_building_systems Services
# get_life_cycle_inventory_building_systems Wall_ext_ag
# get_life_cycle_inventory_building_systems Wall_ext_bg
# get_life_cycle_inventory_building_systems Wall_int_nosup
# get_life_cycle_inventory_building_systems Wall_int_sup
# get_life_cycle_inventory_building_systems Win_ext
# get_life_cycle_inventory_building_systems building_use
# get_life_cycle_inventory_building_systems standard
# get_life_cycle_inventory_building_systems year_end
# get_life_cycle_inventory_building_systems year_start
# get_life_cycle_inventory_building_systems Excavation
# get_life_cycle_inventory_building_systems Floor_g
# get_life_cycle_inventory_building_systems Floor_int
# get_life_cycle_inventory_building_systems Roof
# get_life_cycle_inventory_building_systems Services
# get_life_cycle_inventory_building_systems Wall_ext_ag
# get_life_cycle_inventory_building_systems Wall_ext_bg
# get_life_cycle_inventory_building_systems Wall_int_nosup
# get_life_cycle_inventory_building_systems Wall_int_sup
# get_life_cycle_inventory_building_systems Win_ext
# get_life_cycle_inventory_building_systems building_use
# get_life_cycle_inventory_building_systems standard
# get_life_cycle_inventory_building_systems year_end
# get_life_cycle_inventory_building_systems year_start
# get_life_cycle_inventory_supply_systems Description
# get_life_cycle_inventory_supply_systems code
# get_life_cycle_inventory_supply_systems eff_cs
# get_life_cycle_inventory_supply_systems reference
# get_life_cycle_inventory_supply_systems scale_cs
# get_life_cycle_inventory_supply_systems source_cs
# get_life_cycle_inventory_supply_systems Description
# get_life_cycle_inventory_supply_systems code
# get_life_cycle_inventory_supply_systems eff_dhw
# get_life_cycle_inventory_supply_systems reference
# get_life_cycle_inventory_supply_systems scale_dhw
# get_life_cycle_inventory_supply_systems source_dhw
# get_life_cycle_inventory_supply_systems Description
# get_life_cycle_inventory_supply_systems code
# get_life_cycle_inventory_supply_systems eff_el
# get_life_cycle_inventory_supply_systems reference
# get_life_cycle_inventory_supply_systems scale_el
# get_life_cycle_inventory_supply_systems source_el
# get_life_cycle_inventory_supply_systems Description
# get_life_cycle_inventory_supply_systems code
# get_life_cycle_inventory_supply_systems eff_hs
# get_life_cycle_inventory_supply_systems reference
# get_life_cycle_inventory_supply_systems scale_hs
# get_life_cycle_inventory_supply_systems source_hs
# get_life_cycle_inventory_supply_systems CO2
# get_life_cycle_inventory_supply_systems Description
# get_life_cycle_inventory_supply_systems PEN
# get_life_cycle_inventory_supply_systems code
# get_life_cycle_inventory_supply_systems costs_kWh
# get_life_cycle_inventory_supply_systems reference
# get_multi_criteria_analysis Capex_a_sys_USD
# get_multi_criteria_analysis Capex_a_sys_connected_USD
# get_multi_criteria_analysis Capex_a_sys_disconnected_USD
# get_multi_criteria_analysis Capex_total_sys_USD
# get_multi_criteria_analysis Capex_total_sys_connected_USD
# get_multi_criteria_analysis Capex_total_sys_disconnected_USD
# get_multi_criteria_analysis GHG_rank
# get_multi_criteria_analysis GHG_sys_connected_tonCO2
# get_multi_criteria_analysis GHG_sys_disconnected_tonCO2
# get_multi_criteria_analysis GHG_sys_tonCO2
# get_multi_criteria_analysis Opex_a_sys_USD
# get_multi_criteria_analysis Opex_a_sys_connected_USD
# get_multi_criteria_analysis Opex_a_sys_disconnected_USD
# get_multi_criteria_analysis PEN_rank
# get_multi_criteria_analysis PEN_sys_MJoil
# get_multi_criteria_analysis PEN_sys_connected_MJoil
# get_multi_criteria_analysis PEN_sys_disconnected_MJoil
# get_multi_criteria_analysis TAC_rank
# get_multi_criteria_analysis TAC_sys_USD
# get_multi_criteria_analysis TAC_sys_connected_USD
# get_multi_criteria_analysis TAC_sys_disconnected_USD
# get_multi_criteria_analysis Unnamed: 0
# get_multi_criteria_analysis Unnamed: 0.1
# get_multi_criteria_analysis generation
# get_multi_criteria_analysis individual
# get_multi_criteria_analysis individual_name
# get_multi_criteria_analysis normalized_Capex_total
# get_multi_criteria_analysis normalized_Opex
# get_multi_criteria_analysis normalized_TAC
# get_multi_criteria_analysis normalized_emissions
# get_multi_criteria_analysis normalized_prim
# get_multi_criteria_analysis user_MCDA
# get_multi_criteria_analysis user_MCDA_rank
# get_network_energy_pumping_requirements_file pressure_loss_return_kW
# get_network_energy_pumping_requirements_file pressure_loss_substations_kW
# get_network_energy_pumping_requirements_file pressure_loss_supply_kW
# get_network_energy_pumping_requirements_file pressure_loss_total_kW
# get_network_layout_edges_shapefile Name
# get_network_layout_edges_shapefile Pipe_DN
# get_network_layout_edges_shapefile Type_mat
# get_network_layout_edges_shapefile geometry
# get_network_layout_edges_shapefile weight
# get_network_layout_nodes_shapefile Building
# get_network_layout_nodes_shapefile Name
# get_network_layout_nodes_shapefile Type
# get_network_layout_nodes_shapefile geometry
# get_network_linear_pressure_drop_edges PIPE0
# get_network_linear_thermal_loss_edges_file PIPE0
# get_network_node_types_csv_file Building
# get_network_node_types_csv_file Name
# get_network_node_types_csv_file Q_hex_h_ahu
# get_network_node_types_csv_file Q_hex_h_aru
# get_network_node_types_csv_file Q_hex_h_shu
# get_network_node_types_csv_file Q_hex_h_ww
# get_network_node_types_csv_file Q_hex_plant_kW
# get_network_node_types_csv_file Type
# get_network_node_types_csv_file Unnamed: 0
# get_network_node_types_csv_file coordinates
# get_network_pressure_at_nodes NODE0
# get_network_temperature_plant temperature_return_K
# get_network_temperature_plant temperature_supply_K
# get_network_temperature_return_nodes_file NODE0
# get_network_temperature_supply_nodes_file NODE0
# get_network_thermal_loss_edges_file PIPE0
# get_network_total_pressure_drop_file pressure_loss_return_Pa
# get_network_total_pressure_drop_file pressure_loss_substations_Pa
# get_network_total_pressure_drop_file pressure_loss_supply_Pa
# get_network_total_pressure_drop_file pressure_loss_total_Pa
# get_network_total_thermal_loss_file thermal_loss_return_kW
# get_network_total_thermal_loss_file thermal_loss_supply_kW
# get_network_total_thermal_loss_file thermal_loss_total_kW
# get_node_mass_flow_csv_file NODE0
# get_node_mass_flow_csv_file Unnamed: 0
# get_optimization_checkpoint difference_generational_distances
# get_optimization_checkpoint generation
# get_optimization_checkpoint generational_distances
# get_optimization_checkpoint selected_population
# get_optimization_checkpoint tested_population
# get_optimization_connected_cooling_capacity Capacity_ACHHT_FP_cool_disconnected_W
# get_optimization_connected_cooling_capacity Capacity_ACH_SC_FP_cool_disconnected_W
# get_optimization_connected_cooling_capacity Capacity_BaseVCC_AS_cool_disconnected_W
# get_optimization_connected_cooling_capacity Capacity_DX_AS_cool_disconnected_W
# get_optimization_connected_cooling_capacity Capacity_VCCHT_AS_cool_disconnected_W
# get_optimization_connected_cooling_capacity Capaticy_ACH_SC_ET_cool_disconnected_W
# get_optimization_connected_cooling_capacity Name
# get_optimization_connected_electricity_capacity Capacity_GRID_el_connected_W
# get_optimization_connected_electricity_capacity Capacity_PV_el_connected_W
# get_optimization_connected_electricity_capacity Capacity_PV_el_connected_m2
# get_optimization_connected_heating_capacity Capacity_BackupBoiler_NG_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_BaseBoiler_NG_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_CHP_DB_el_connected_W
# get_optimization_connected_heating_capacity Capacity_CHP_DB_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_CHP_NG_el_connected_W
# get_optimization_connected_heating_capacity Capacity_CHP_NG_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_CHP_WB_el_connected_W
# get_optimization_connected_heating_capacity Capacity_CHP_WB_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_HP_DS_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_HP_GS_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_HP_SS_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_HP_WS_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_PVT_connected_m2
# get_optimization_connected_heating_capacity Capacity_PVT_el_connected_W
# get_optimization_connected_heating_capacity Capacity_PVT_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_PeakBoiler_NG_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_SC_ET_connected_m2
# get_optimization_connected_heating_capacity Capacity_SC_ET_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_SC_FP_connected_m2
# get_optimization_connected_heating_capacity Capacity_SC_FP_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_SeasonalStorage_WS_heat_connected_W
# get_optimization_connected_heating_capacity Capacity_SeasonalStorage_WS_heat_connected_m3
# get_optimization_decentralized_folder_building_result_heating Best configuration
# get_optimization_decentralized_folder_building_result_heating Capacity_BaseBoiler_NG_W
# get_optimization_decentralized_folder_building_result_heating Capacity_FC_NG_W
# get_optimization_decentralized_folder_building_result_heating Capacity_GS_HP_W
# get_optimization_decentralized_folder_building_result_heating Capex_a_USD
# get_optimization_decentralized_folder_building_result_heating Capex_total_USD
# get_optimization_decentralized_folder_building_result_heating GHG_tonCO2
# get_optimization_decentralized_folder_building_result_heating Nominal heating load
# get_optimization_decentralized_folder_building_result_heating Opex_fixed_USD
# get_optimization_decentralized_folder_building_result_heating Opex_var_USD
# get_optimization_decentralized_folder_building_result_heating PEN_MJoil
# get_optimization_decentralized_folder_building_result_heating TAC_USD
# get_optimization_decentralized_folder_building_result_heating Unnamed: 0
# get_optimization_decentralized_folder_building_result_heating_activation BackupBoiler_Status
# get_optimization_decentralized_folder_building_result_heating_activation Boiler_Status
# get_optimization_decentralized_folder_building_result_heating_activation E_hs_ww_req_W
# get_optimization_decentralized_folder_building_result_heating_activation GHP_Status
# get_optimization_decentralized_folder_building_result_heating_activation NG_BackupBoiler_req_Wh
# get_optimization_decentralized_folder_building_result_heating_activation NG_Boiler_req_Wh
# get_optimization_decentralized_folder_building_result_heating_activation Q_BackupBoiler_gen_directload_W
# get_optimization_decentralized_folder_building_result_heating_activation Q_Boiler_gen_directload_W
# get_optimization_decentralized_folder_building_result_heating_activation Q_GHP_gen_directload_W
# get_optimization_decentralized_folder_building_result_heating_activation Unnamed: 0
# get_optimization_disconnected_cooling_capacity Capacity_ACHHT_FP_cool_disconnected_W
# get_optimization_disconnected_cooling_capacity Capacity_ACH_SC_FP_cool_disconnected_W
# get_optimization_disconnected_cooling_capacity Capacity_BaseVCC_AS_cool_disconnected_W
# get_optimization_disconnected_cooling_capacity Capacity_DX_AS_cool_disconnected_W
# get_optimization_disconnected_cooling_capacity Capacity_VCCHT_AS_cool_disconnected_W
# get_optimization_disconnected_cooling_capacity Capaticy_ACH_SC_ET_cool_disconnected_W
# get_optimization_disconnected_cooling_capacity Name
# get_optimization_disconnected_heating_capacity Capacity_BaseBoiler_NG_heat_disconnected_W
# get_optimization_disconnected_heating_capacity Capacity_FC_NG_heat_disconnected_W
# get_optimization_disconnected_heating_capacity Capacity_GS_HP_heat_disconnected_W
# get_optimization_disconnected_heating_capacity Name
# get_optimization_generation_connected_performance Capex_a_BackupBoiler_NG_connected_USD
# get_optimization_generation_connected_performance Capex_a_BaseBoiler_NG_connected_USD
# get_optimization_generation_connected_performance Capex_a_CHP_NG_connected_USD
# get_optimization_generation_connected_performance Capex_a_DHN_connected_USD
# get_optimization_generation_connected_performance Capex_a_Furnace_dry_connected_USD
# get_optimization_generation_connected_performance Capex_a_Furnace_wet_connected_USD
# get_optimization_generation_connected_performance Capex_a_GHP_connected_USD
# get_optimization_generation_connected_performance Capex_a_GRID_connected_USD
# get_optimization_generation_connected_performance Capex_a_HP_Lake_connected_USD
# get_optimization_generation_connected_performance Capex_a_HP_Server_connected_USD
# get_optimization_generation_connected_performance Capex_a_HP_Sewage_connected_USD
# get_optimization_generation_connected_performance Capex_a_PVT_connected_USD
# get_optimization_generation_connected_performance Capex_a_PV_connected_USD
# get_optimization_generation_connected_performance Capex_a_PeakBoiler_NG_connected_USD
# get_optimization_generation_connected_performance Capex_a_SC_ET_connected_USD
# get_optimization_generation_connected_performance Capex_a_SC_FP_connected_USD
# get_optimization_generation_connected_performance Capex_a_SeasonalStorage_WS_connected_USD
# get_optimization_generation_connected_performance Capex_a_SubstationsHeating_connected_USD
# get_optimization_generation_connected_performance Capex_total_BackupBoiler_NG_connected_USD
# get_optimization_generation_connected_performance Capex_total_BaseBoiler_NG_connected_USD
# get_optimization_generation_connected_performance Capex_total_CHP_NG_connected_USD
# get_optimization_generation_connected_performance Capex_total_DHN_connected_USD
# get_optimization_generation_connected_performance Capex_total_Furnace_dry_connected_USD
# get_optimization_generation_connected_performance Capex_total_Furnace_wet_connected_USD
# get_optimization_generation_connected_performance Capex_total_GHP_connected_USD
# get_optimization_generation_connected_performance Capex_total_GRID_connected_USD
# get_optimization_generation_connected_performance Capex_total_HP_Lake_connected_USD
# get_optimization_generation_connected_performance Capex_total_HP_Server_connected_USD
# get_optimization_generation_connected_performance Capex_total_HP_Sewage_connected_USD
# get_optimization_generation_connected_performance Capex_total_PVT_connected_USD
# get_optimization_generation_connected_performance Capex_total_PV_connected_USD
# get_optimization_generation_connected_performance Capex_total_PeakBoiler_NG_connected_USD
# get_optimization_generation_connected_performance Capex_total_SC_ET_connected_USD
# get_optimization_generation_connected_performance Capex_total_SC_FP_connected_USD
# get_optimization_generation_connected_performance Capex_total_SeasonalStorage_WS_connected_USD
# get_optimization_generation_connected_performance Capex_total_SubstationsHeating_connected_USD
# get_optimization_generation_connected_performance GHG_DB_connected_tonCO2yr
# get_optimization_generation_connected_performance GHG_GRID_exports_connected_tonCO2yr
# get_optimization_generation_connected_performance GHG_GRID_imports_connected_tonCO2yr
# get_optimization_generation_connected_performance GHG_NG_connected_tonCO2yr
# get_optimization_generation_connected_performance GHG_WB_connected_tonCO2yr
# get_optimization_generation_connected_performance Opex_fixed_BackupBoiler_NG_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_BaseBoiler_NG_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_CHP_NG_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_DHN_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_Furnace_dry_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_Furnace_wet_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_GHP_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_GRID_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_HP_Lake_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_HP_Server_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_HP_Sewage_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_PVT_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_PV_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_PeakBoiler_NG_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_SC_ET_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_SC_FP_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_SeasonalStorage_WS_connected_USD
# get_optimization_generation_connected_performance Opex_fixed_SubstationsHeating_connected_USD
# get_optimization_generation_connected_performance Opex_var_DB_connected_USD
# get_optimization_generation_connected_performance Opex_var_GRID_exports_connected_USD
# get_optimization_generation_connected_performance Opex_var_GRID_imports_connected_USD
# get_optimization_generation_connected_performance Opex_var_NG_connected_USD
# get_optimization_generation_connected_performance Opex_var_WB_connected_USD
# get_optimization_generation_connected_performance PEN_DB_connected_MJoilyr
# get_optimization_generation_connected_performance PEN_GRID_exports_connected_MJoilyr
# get_optimization_generation_connected_performance PEN_GRID_imports_connected_MJoilyr
# get_optimization_generation_connected_performance PEN_NG_connected_MJoilyr
# get_optimization_generation_connected_performance PEN_WB_connected_MJoilyr
# get_optimization_generation_connected_performance Unnamed: 0
# get_optimization_generation_connected_performance generation
# get_optimization_generation_connected_performance individual
# get_optimization_generation_connected_performance individual_name
# get_optimization_generation_disconnected_performance Capex_a_cooling_disconnected_USD
# get_optimization_generation_disconnected_performance Capex_a_heating_disconnected_USD
# get_optimization_generation_disconnected_performance Capex_total_cooling_disconnected_USD
# get_optimization_generation_disconnected_performance Capex_total_heating_disconnected_USD
# get_optimization_generation_disconnected_performance GHG_cooling_disconnected_tonCO2
# get_optimization_generation_disconnected_performance GHG_heating_disconnected_tonCO2
# get_optimization_generation_disconnected_performance Opex_fixed_cooling_disconnected_USD
# get_optimization_generation_disconnected_performance Opex_fixed_heating_disconnected_USD
# get_optimization_generation_disconnected_performance Opex_var_cooling_disconnected_USD
# get_optimization_generation_disconnected_performance Opex_var_heating_disconnected_USD
# get_optimization_generation_disconnected_performance PEN_cooling_disconnected_MJoil
# get_optimization_generation_disconnected_performance PEN_heating_disconnected_MJoil
# get_optimization_generation_disconnected_performance Unnamed: 0
# get_optimization_generation_disconnected_performance generation
# get_optimization_generation_disconnected_performance individual
# get_optimization_generation_disconnected_performance individual_name
# get_optimization_generation_total_performance Capex_a_sys_USD
# get_optimization_generation_total_performance Capex_a_sys_connected_USD
# get_optimization_generation_total_performance Capex_a_sys_disconnected_USD
# get_optimization_generation_total_performance Capex_total_sys_USD
# get_optimization_generation_total_performance Capex_total_sys_connected_USD
# get_optimization_generation_total_performance Capex_total_sys_disconnected_USD
# get_optimization_generation_total_performance GHG_sys_connected_tonCO2
# get_optimization_generation_total_performance GHG_sys_disconnected_tonCO2
# get_optimization_generation_total_performance GHG_sys_tonCO2
# get_optimization_generation_total_performance Opex_a_sys_USD
# get_optimization_generation_total_performance Opex_a_sys_connected_USD
# get_optimization_generation_total_performance Opex_a_sys_disconnected_USD
# get_optimization_generation_total_performance PEN_sys_MJoil
# get_optimization_generation_total_performance PEN_sys_connected_MJoil
# get_optimization_generation_total_performance PEN_sys_disconnected_MJoil
# get_optimization_generation_total_performance TAC_sys_USD
# get_optimization_generation_total_performance TAC_sys_connected_USD
# get_optimization_generation_total_performance TAC_sys_disconnected_USD
# get_optimization_generation_total_performance Unnamed: 0
# get_optimization_generation_total_performance generation
# get_optimization_generation_total_performance individual
# get_optimization_generation_total_performance individual_name
# get_optimization_generation_total_performance_halloffame Capex_a_sys_USD
# get_optimization_generation_total_performance_halloffame Capex_a_sys_connected_USD
# get_optimization_generation_total_performance_halloffame Capex_a_sys_disconnected_USD
# get_optimization_generation_total_performance_halloffame Capex_total_sys_USD
# get_optimization_generation_total_performance_halloffame Capex_total_sys_connected_USD
# get_optimization_generation_total_performance_halloffame Capex_total_sys_disconnected_USD
# get_optimization_generation_total_performance_halloffame GHG_sys_connected_tonCO2
# get_optimization_generation_total_performance_halloffame GHG_sys_disconnected_tonCO2
# get_optimization_generation_total_performance_halloffame GHG_sys_tonCO2
# get_optimization_generation_total_performance_halloffame Opex_a_sys_USD
# get_optimization_generation_total_performance_halloffame Opex_a_sys_connected_USD
# get_optimization_generation_total_performance_halloffame Opex_a_sys_disconnected_USD
# get_optimization_generation_total_performance_halloffame PEN_sys_MJoil
# get_optimization_generation_total_performance_halloffame PEN_sys_connected_MJoil
# get_optimization_generation_total_performance_halloffame PEN_sys_disconnected_MJoil
# get_optimization_generation_total_performance_halloffame TAC_sys_USD
# get_optimization_generation_total_performance_halloffame TAC_sys_connected_USD
# get_optimization_generation_total_performance_halloffame TAC_sys_disconnected_USD
# get_optimization_generation_total_performance_halloffame Unnamed: 0
# get_optimization_generation_total_performance_halloffame generation
# get_optimization_generation_total_performance_halloffame individual
# get_optimization_generation_total_performance_halloffame individual_name
# ...
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems a_e
# get_supply_systems a_g
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems c
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems e
# get_supply_systems e_e
# get_supply_systems e_g
# get_supply_systems el_W
# get_supply_systems m_cw
# get_supply_systems m_hw
# get_supply_systems r_e
# get_supply_systems r_g
# get_supply_systems s_e
# get_supply_systems s_g
# get_supply_systems type
# get_supply_systems unit
# get_supply_systems Description
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems c
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems e
# get_supply_systems unit
# get_supply_systems Description
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems c
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems e
# get_supply_systems unit
# get_supply_systems Description
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems c
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems e
# get_supply_systems unit
# get_supply_systems Description
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems c
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems e
# get_supply_systems unit
# get_supply_systems Description
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems c
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems e
# get_supply_systems unit
# get_supply_systems  Assumptions
# get_supply_systems Description
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems b
# get_supply_systems c
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems e
# get_supply_systems unit
# get_supply_systems Description
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems c
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems e
# get_supply_systems unit
# get_supply_systems Currency
# get_supply_systems Description
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems a_p
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems b_p
# get_supply_systems c
# get_supply_systems c_p
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems d
# get_supply_systems d_p
# get_supply_systems e
# get_supply_systems e_p
# get_supply_systems unit
# get_supply_systems Description
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems c
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems e
# get_supply_systems unit
# get_supply_systems Description
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems PV_Bref
# get_supply_systems PV_a0
# get_supply_systems PV_a1
# get_supply_systems PV_a2
# get_supply_systems PV_a3
# get_supply_systems PV_a4
# get_supply_systems PV_n
# get_supply_systems PV_noct
# get_supply_systems PV_th
# get_supply_systems a
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems c
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems e
# get_supply_systems misc_losses
# get_supply_systems module_length_m
# get_supply_systems type
# get_supply_systems unit
# get_supply_systems Description
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems c
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems e
# get_supply_systems unit
# get_supply_systems Currency
# get_supply_systems Description
# get_supply_systems Diameter_max
# get_supply_systems Diameter_min
# get_supply_systems Investment
# get_supply_systems Unit
# get_supply_systems assumption
# get_supply_systems Description
# get_supply_systems assumption
# get_supply_systems currency
# get_supply_systems value
# get_supply_systems Description
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems c
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems e
# get_supply_systems unit
# get_supply_systems C_eff
# get_supply_systems Cp_fluid
# get_supply_systems Description
# get_supply_systems IAM_d
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems aperture_area_ratio
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems c
# get_supply_systems c1
# get_supply_systems c2
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems dP1
# get_supply_systems dP2
# get_supply_systems dP3
# get_supply_systems dP4
# get_supply_systems e
# get_supply_systems mB0_r
# get_supply_systems mB_max_r
# get_supply_systems mB_min_r
# get_supply_systems module_area_m2
# get_supply_systems module_length_m
# get_supply_systems n0
# get_supply_systems t_max
# get_supply_systems type
# get_supply_systems unit
# get_supply_systems Description
# get_supply_systems IR_%
# get_supply_systems LT_yr
# get_supply_systems O&M_%
# get_supply_systems a
# get_supply_systems assumption
# get_supply_systems b
# get_supply_systems c
# get_supply_systems cap_max
# get_supply_systems cap_min
# get_supply_systems code
# get_supply_systems currency
# get_supply_systems d
# get_supply_systems e
# get_supply_systems unit
# get_surroundings_geometry Name
# get_surroundings_geometry floors_ag
# get_surroundings_geometry geometry
# get_surroundings_geometry height_ag
# get_technical_emission_systems Description
# get_technical_emission_systems code
# get_technical_emission_systems dT_Qcs
# get_technical_emission_systems dT_Qhs
# get_technical_emission_systems Description
# get_technical_emission_systems Qcsmax_Wm2
# get_technical_emission_systems Tc_sup_air_ahu_C
# get_technical_emission_systems Tc_sup_air_aru_C
# get_technical_emission_systems Tscs0_ahu_C
# get_technical_emission_systems Tscs0_aru_C
# get_technical_emission_systems Tscs0_scu_C
# get_technical_emission_systems code
# get_technical_emission_systems dTcs0_ahu_C
# get_technical_emission_systems dTcs0_aru_C
# get_technical_emission_systems dTcs0_scu_C
# get_technical_emission_systems dTcs_C
# get_technical_emission_systems Description
# get_technical_emission_systems Qwwmax_Wm2
# get_technical_emission_systems Tsww0_C
# get_technical_emission_systems code
# get_technical_emission_systems Description
# get_technical_emission_systems Qhsmax_Wm2
# get_technical_emission_systems Th_sup_air_ahu_C
# get_technical_emission_systems Th_sup_air_aru_C
# get_technical_emission_systems Tshs0_ahu_C
# get_technical_emission_systems Tshs0_aru_C
# get_technical_emission_systems Tshs0_shu_C
# get_technical_emission_systems code
# get_technical_emission_systems dThs0_ahu_C
# get_technical_emission_systems dThs0_aru_C
# get_technical_emission_systems dThs0_shu_C
# get_technical_emission_systems dThs_C
# get_technical_emission_systems Description
# get_technical_emission_systems ECONOMIZER
# get_technical_emission_systems HEAT_REC
# get_technical_emission_systems MECH_VENT
# get_technical_emission_systems NIGHT_FLSH
# get_technical_emission_systems WIN_VENT
# get_technical_emission_systems code
# get_terrain Mock_variable
# get_thermal_demand_csv_file B001
# get_thermal_demand_csv_file Unnamed: 0
# get_thermal_network_edge_list_file D_int_m
# get_thermal_network_edge_list_file Pipe_DN
# get_thermal_network_edge_list_file Type_mat
# get_thermal_network_edge_list_file length_m
# get_thermal_network_layout_massflow_edges_file PIPE0
# get_thermal_network_layout_massflow_nodes_file NODE0
# get_thermal_network_layout_pressure_drop_kw_file pressure_loss_return_kW
# get_thermal_network_layout_pressure_drop_kw_file pressure_loss_substations_kW
# get_thermal_network_layout_pressure_drop_kw_file pressure_loss_supply_kW
# get_thermal_network_layout_pressure_drop_kw_file pressure_loss_total_kW
# get_thermal_network_node_types_csv_file Building
# get_thermal_network_node_types_csv_file Type
# get_thermal_network_plant_heat_requirement_file NONE
# get_thermal_network_pressure_losses_edges_file PIPE0
# get_thermal_network_qloss_system_file PIPE0
# get_thermal_network_substation_ploss_file B01
# get_thermal_network_velocity_edges_file PIPE0
# get_thermal_networks Cp_JkgK
# get_thermal_networks code
# get_thermal_networks lambda_WmK
# get_thermal_networks material
# get_thermal_networks rho_kgm3
# get_thermal_networks D_ext_m
# get_thermal_networks D_ins_m
# get_thermal_networks D_int_m
# get_thermal_networks Pipe_DN
# get_thermal_networks Vdot_max_m3s
# get_thermal_networks Vdot_min_m3s
# get_total_demand Af_m2
# get_total_demand Aocc_m2
# get_total_demand Aroof_m2
# get_total_demand COAL_hs0_kW
# get_total_demand COAL_hs_MWhyr
# get_total_demand COAL_ww0_kW
# get_total_demand COAL_ww_MWhyr
# get_total_demand DC_cdata0_kW
# get_total_demand DC_cdata_MWhyr
# get_total_demand DC_cre0_kW
# get_total_demand DC_cre_MWhyr
# get_total_demand DC_cs0_kW
# get_total_demand DC_cs_MWhyr
# get_total_demand DH_hs0_kW
# get_total_demand DH_hs_MWhyr
# get_total_demand DH_ww0_kW
# get_total_demand DH_ww_MWhyr
# get_total_demand E_cdata0_kW
# get_total_demand E_cdata_MWhyr
# get_total_demand E_cre0_kW
# get_total_demand E_cre_MWhyr
# get_total_demand E_cs0_kW
# get_total_demand E_cs_MWhyr
# get_total_demand E_hs0_kW
# get_total_demand E_hs_MWhyr
# get_total_demand E_sys0_kW
# get_total_demand E_sys_MWhyr
# get_total_demand E_ww0_kW
# get_total_demand E_ww_MWhyr
# get_total_demand Eal0_kW
# get_total_demand Eal_MWhyr
# get_total_demand Eaux0_kW
# get_total_demand Eaux_MWhyr
# get_total_demand Edata0_kW
# get_total_demand Edata_MWhyr
# get_total_demand Epro0_kW
# get_total_demand Epro_MWhyr
# get_total_demand GFA_m2
# get_total_demand GRID0_kW
# get_total_demand GRID_MWhyr
# get_total_demand NG_hs0_kW
# get_total_demand NG_hs_MWhyr
# get_total_demand NG_ww0_kW
# get_total_demand NG_ww_MWhyr
# get_total_demand Name
# get_total_demand OIL_hs0_kW
# get_total_demand OIL_hs_MWhyr
# get_total_demand OIL_ww0_kW
# get_total_demand OIL_ww_MWhyr
# get_total_demand PV0_kW
# get_total_demand PV_MWhyr
# get_total_demand QC_sys0_kW
# get_total_demand QC_sys_MWhyr
# get_total_demand QH_sys0_kW
# get_total_demand QH_sys_MWhyr
# get_total_demand Qcdata0_kW
# get_total_demand Qcdata_MWhyr
# get_total_demand Qcdata_sys0_kW
# get_total_demand Qcdata_sys_MWhyr
# get_total_demand Qcpro_sys0_kW
# get_total_demand Qcpro_sys_MWhyr
# get_total_demand Qcre0_kW
# get_total_demand Qcre_MWhyr
# get_total_demand Qcre_sys0_kW
# get_total_demand Qcre_sys_MWhyr
# get_total_demand Qcs0_kW
# get_total_demand Qcs_MWhyr
# get_total_demand Qcs_dis_ls0_kW
# get_total_demand Qcs_dis_ls_MWhyr
# get_total_demand Qcs_em_ls0_kW
# get_total_demand Qcs_em_ls_MWhyr
# get_total_demand Qcs_lat_ahu0_kW
# get_total_demand Qcs_lat_ahu_MWhyr
# get_total_demand Qcs_lat_aru0_kW
# get_total_demand Qcs_lat_aru_MWhyr
# get_total_demand Qcs_lat_sys0_kW
# get_total_demand Qcs_lat_sys_MWhyr
# get_total_demand Qcs_sen_ahu0_kW
# get_total_demand Qcs_sen_ahu_MWhyr
# get_total_demand Qcs_sen_aru0_kW
# get_total_demand Qcs_sen_aru_MWhyr
# get_total_demand Qcs_sen_scu0_kW
# get_total_demand Qcs_sen_scu_MWhyr
# get_total_demand Qcs_sen_sys0_kW
# get_total_demand Qcs_sen_sys_MWhyr
# get_total_demand Qcs_sys0_kW
# get_total_demand Qcs_sys_MWhyr
# get_total_demand Qcs_sys_ahu0_kW
# get_total_demand Qcs_sys_ahu_MWhyr
# get_total_demand Qcs_sys_aru0_kW
# get_total_demand Qcs_sys_aru_MWhyr
# get_total_demand Qcs_sys_scu0_kW
# get_total_demand Qcs_sys_scu_MWhyr
# get_total_demand Qhpro_sys0_kW
# get_total_demand Qhpro_sys_MWhyr
# get_total_demand Qhs0_kW
# get_total_demand Qhs_MWhyr
# get_total_demand Qhs_dis_ls0_kW
# get_total_demand Qhs_dis_ls_MWhyr
# get_total_demand Qhs_em_ls0_kW
# get_total_demand Qhs_em_ls_MWhyr
# get_total_demand Qhs_lat_ahu0_kW
# get_total_demand Qhs_lat_ahu_MWhyr
# get_total_demand Qhs_lat_aru0_kW
# get_total_demand Qhs_lat_aru_MWhyr
# get_total_demand Qhs_lat_sys0_kW
# get_total_demand Qhs_lat_sys_MWhyr
# get_total_demand Qhs_sen_ahu0_kW
# get_total_demand Qhs_sen_ahu_MWhyr
# get_total_demand Qhs_sen_aru0_kW
# get_total_demand Qhs_sen_aru_MWhyr
# get_total_demand Qhs_sen_shu0_kW
# get_total_demand Qhs_sen_shu_MWhyr
# get_total_demand Qhs_sen_sys0_kW
# get_total_demand Qhs_sen_sys_MWhyr
# get_total_demand Qhs_sys0_kW
# get_total_demand Qhs_sys_MWhyr
# get_total_demand Qhs_sys_ahu0_kW
# get_total_demand Qhs_sys_ahu_MWhyr
# get_total_demand Qhs_sys_aru0_kW
# get_total_demand Qhs_sys_aru_MWhyr
# get_total_demand Qhs_sys_shu0_kW
# get_total_demand Qhs_sys_shu_MWhyr
# get_total_demand Qww0_kW
# get_total_demand Qww_MWhyr
# get_total_demand Qww_sys0_kW
# get_total_demand Qww_sys_MWhyr
# get_total_demand SOLAR_hs0_kW
# get_total_demand SOLAR_hs_MWhyr
# get_total_demand SOLAR_ww0_kW
# get_total_demand SOLAR_ww_MWhyr
# get_total_demand WOOD_hs0_kW
# get_total_demand WOOD_hs_MWhyr
# get_total_demand WOOD_ww0_kW
# get_total_demand WOOD_ww_MWhyr
# get_total_demand people0
# get_water_body_potential QLake_kW
# get_water_body_potential Ts_C
# get_weather EPW file variables
# get_weather_file Albedo (index = 32)
# get_weather_file aerosol_opt_thousandths (index = 29)
# get_weather_file atmos_Pa (index = 9)
# get_weather_file ceiling_hgt_m (index = 25)
# get_weather_file datasource (index = 5)
# get_weather_file day (index = 2)
# get_weather_file days_last_snow (index = 31)
# get_weather_file dewpoint_C (index = 7)
# get_weather_file difhorillum_lux (index = 18)
# get_weather_file difhorrad_Whm2 (index = 15)
# get_weather_file dirnorillum_lux (index = 17)
# get_weather_file dirnorrad_Whm2 (index = 14)
# get_weather_file drybulb_C (index = 6)
# get_weather_file extdirrad_Whm2 (index = 11)
# get_weather_file exthorrad_Whm2 (index = 10)
# get_weather_file glohorillum_lux (index = 16)
# get_weather_file glohorrad_Whm2 (index = 13)
# get_weather_file horirsky_Whm2 (index = 12)
# get_weather_file hour (index = 3)
# get_weather_file liq_precip_depth_mm (index = 33)
# get_weather_file liq_precip_rate_Hour (index = 34)
# get_weather_file minute (index = 4)
# get_weather_file month (index = 1)
# get_weather_file opaqskycvr_tenths (index = 23)
# get_weather_file precip_wtr_mm (index = 28)
# get_weather_file presweathcodes (index = 27)
# get_weather_file presweathobs (index = 26)
# get_weather_file relhum_percent (index = 8)
# get_weather_file snowdepth_cm (index = 30)
# get_weather_file totskycvr_tenths (index = 22)
# get_weather_file visibility_km (index = 24)
# get_weather_file winddir_deg (index = 20)
# get_weather_file windspd_ms (index = 21)
# get_weather_file year (index = 0)
# get_weather_file zenlum_lux (index = 19)
# get_zone_geometry Name
# get_zone_geometry floors_ag
# get_zone_geometry floors_bg
# get_zone_geometry geometry
# get_zone_geometry height_ag
# get_zone_geometry height_bg

# %% [markdown]
# ### make sure glossary.csv (locator_method, variable) is unique
